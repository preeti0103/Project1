# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from datetime import datetime

# %%
region_price = pd.read_csv("housing_prices.csv")
region_price = region_price.dropna()
region_price
# Out:
#           Date                 Area  Composite_HPI  Two_Storey_HPI  \
# 0     Jan 2005  Barrie_and_District          100.0           100.0
# 1     Feb 2005  Barrie_and_District          101.5           101.2
# 2     Mar 2005  Barrie_and_District          102.8           102.9
# 3     Apr 2005  Barrie_and_District          103.5           103.4
# 4     May 2005  Barrie_and_District          104.5           104.0
# ...        ...                  ...            ...             ...
# 1105  Jan 2020      Oakville_Milton          276.4           280.4
# 1106  Feb 2020      Oakville_Milton          284.2           289.9
# 1107  Mar 2020      Oakville_Milton          293.5           300.0
# 1108  Apr 2020      Oakville_Milton          289.2           292.8
# 1109  May 2020      Oakville_Milton          290.0           292.5
#
#       Apartment_HPI  Composite_Benchmark  Two_Storey_Benchmark  \
# 0             100.0             209000.0              220600.0
# ...

# %%
region_price.groupby('Area')['Date'].max()
# Out:
# Area
# Barrie_and_District    Sep 2019
# Greater_Toronto        Sep 2019
# Guelph                 Sep 2019
# Hamilton_Burlington    Sep 2019
# Niagara_Region         Sep 2019
# Oakville_Milton        Sep 2019
# Name: Date, dtype: object

# %%
pd.to_datetime(region_price["Date"],format="%m-%Y")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-82d88601c9c5> in <module>
# ----> 1 pd.to_datetime(region_price["Date"],format="%m-%Y")
#
# ...
