# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from datetime import datetime

# %%
region_price = pd.read_csv("housing_prices.csv")
region_price = region_price.dropna()
region_price
# Out:
#           Date                 Area  Composite_HPI  Two_Storey_HPI  \
# 0     Jan 2005  Barrie_and_District          100.0           100.0
# 1     Feb 2005  Barrie_and_District          101.5           101.2
# 2     Mar 2005  Barrie_and_District          102.8           102.9
# 3     Apr 2005  Barrie_and_District          103.5           103.4
# 4     May 2005  Barrie_and_District          104.5           104.0
# ...        ...                  ...            ...             ...
# 1105  Jan 2020      Oakville_Milton          276.4           280.4
# 1106  Feb 2020      Oakville_Milton          284.2           289.9
# 1107  Mar 2020      Oakville_Milton          293.5           300.0
# 1108  Apr 2020      Oakville_Milton          289.2           292.8
# 1109  May 2020      Oakville_Milton          290.0           292.5
#
#       Apartment_HPI  Composite_Benchmark  Two_Storey_Benchmark  \
# 0             100.0             209000.0              220600.0
# ...

# %%
cy_prices = region_price.loc[region_price['Date']=="May 2020"]
cy_prices
# Out:
#           Date                 Area  Composite_HPI  Two_Storey_HPI  \
# 184   May 2020  Barrie_and_District          247.1           250.1
# 369   May 2020      Greater_Toronto          286.7           279.4
# 554   May 2020               Guelph          238.2           237.5
# 739   May 2020  Hamilton_Burlington          292.8           302.2
# 924   May 2020       Niagara_Region          264.4           263.8
# 1109  May 2020      Oakville_Milton          290.0           292.5
#
#       Apartment_HPI  Composite_Benchmark  Two_Storey_Benchmark  \
# 184           216.2             516400.0              551700.0
# 369           300.0             870000.0             1001100.0
# 554           227.3             592100.0              618100.0
# 739           307.4             659800.0              738200.0
# 924           247.7             456400.0              485300.0
# 1109          266.8            1100000.0             1148100.0
#
#       Apartment_Benchmark
# ...

# %%
plt.bar(cy_prices['Area'],cy_prices['Composite_Benchmark'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.bar(cy_prices['Area'],cy_prices['Composite_Benchmark'])
plt.tight_layout
plt.show()
