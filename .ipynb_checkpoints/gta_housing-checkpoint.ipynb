# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# %%
income_area = pd.read_csv('Resources/income_comparison.csv')
income_area = income_area.dropna()
income_area
# Out:
#    Description    Year Total_Returns  Total_Income Avg_Income  \
# 0      Toronto  2017.0       4814770  253000000000      52547
# 1     Hamilton  2017.0        597420   30975792000      51849
# 2      Niagara  2017.0        335910   14660909000      43645
# 3       Guelph  2017.0        120580    6540254000      54240
# 4       Barrie  2017.0        154660    7442638000      48123
# 5      Toronto  2014.0       4573270  222000000000      48543
# 6     Hamilton  2014.0        576160   27760945000      48183
# 7      Niagara  2014.0        322800   13160517000      40770
# 8       Guelph  2014.0        113670    5671404000      49894
# 9       Barrie  2014.0        146030    6579521000      45056
# 10     Toronto  2010.0       4249280  189000000000      44478
# 11    Hamilton  2010.0        543620   23586427000      43388
# 12     Niagara  2010.0        311730   11659629000      37403
# 13      Guelph  2010.0        105740    4749362000      44915
# 14      Barrie  2010.0        140360    5751240000      40975
#
#    under80K_avg_income under80K_total_returns over80K_avg_income  \
# 0                36945                3964740              92979
# 1                41337                 489400              81285
# 2                39015                 293690              65456
# 3                44067                  97490              78722
# 4                40931                 128350              72991
# 5                35733                3864830              86850
# 6                39926                 484570              74966
# 7                37109                 287130              61565
# 8                42655                  94740              71105
# 9                39639                 124130              66527
# 10               34365                3710040              80144
# 11               37912                 475800              67021
# 12               35234                 284290              56262
# 13               39958                  91800              64239
# 14               38179                 123900              58258
#
#    over80K_total_returns   10000  ...   45000   50000   60000   70000   80000  \
# 0                 850050  920380  ...  207420  197570  316850  256120  212420
# 1                 107990   83120  ...   30700   29530   45390   36620   30080
# 2                  42230   44040  ...   18970   18070   25400   18510   14140
# 3                  23100   15910  ...    6290    6690   10660    8170    6490
# 4                  26310   21890  ...    7700    7380   11680    9490    7780
# 5                 708440  948480  ...  202000  180250  297590  236640  192290
# 6                  91610   86870  ...   31040   26840   43680   34220   27300
# 7                  35680   47330  ...   18740   15290   23420   16390   12190
# 8                  18930   16320  ...    6340    5900   10140    7600    5790
# 9                  21940   22640  ...    7660    6580   11170    8540    7130
# 10                539230  951670  ...  193230  169040  274540  211130  161080
# 11                 67820   92940  ...   29270   25130   39600   30470   23610
# 12                 27440   51360  ...   17590   13940   21170   14500   10460
# 13                 13950   17320  ...    6180    5550    8890    6510    4760
# 14                 16470   24570  ...    7470    6430   10270    8110    6490
#
#      90000  100000  150000  250000 500000
# 0   168910  151070  309470  139870  80730
# 1    23380   21290   39840   16240   7240
# 2    10110    9250   15360    5320   2190
# 3     4980    4530    8520    3610   1460
# 4     6200    5710    9980    3210   1210
# 5   151480  128880  253980  108170  65930
# 6    21290   19140   33060   12380   5740
# 7     9200    7840   12940    4020   1680
# 8     4540    3670    6990    2680   1050
# 9     5730    4830    8060    2490    830
# 10  126760   95840  184210   79140  53280
# 11   18860   13090   22600    8830   4440
# 12    8080    5600    9430    2910   1420
# 13    3830    2610    4870    1860    780
# 14    4960    3440    5720    1660    690
#
# [15 rows x 26 columns]

# %%
# income_area['Avg_Income'] = (income_area['Total_Income'])/(income_area['Total_Returns'])
income = income_area[['Total_Returns', 'Total_Income', 'Avg_Income',
       'under80K_avg_income', 'under80K_total_returns', 'over80K_avg_income',
       'over80K_total_returns', '10000',
       '15000', '20000', '25000', '30000', '35000', '40000', '45000', '50000',
       '60000', '70000', '80000', '90000', '100000', '150000', '250000',
       '500000']].astype(float)

# %%
income[['Region','Year']] = income_area[['Description','Year']]
income.set_index(['Region','Year'])
# Out:
#                  Total_Returns  Total_Income  Avg_Income  under80K_avg_income  \
# Region   Year
# Toronto  2017.0      4814770.0  2.530000e+11     52547.0              36945.0
# Hamilton 2017.0       597420.0  3.097579e+10     51849.0              41337.0
# Niagara  2017.0       335910.0  1.466091e+10     43645.0              39015.0
# Guelph   2017.0       120580.0  6.540254e+09     54240.0              44067.0
# Barrie   2017.0       154660.0  7.442638e+09     48123.0              40931.0
# Toronto  2014.0      4573270.0  2.220000e+11     48543.0              35733.0
# Hamilton 2014.0       576160.0  2.776094e+10     48183.0              39926.0
# Niagara  2014.0       322800.0  1.316052e+10     40770.0              37109.0
# Guelph   2014.0       113670.0  5.671404e+09     49894.0              42655.0
# Barrie   2014.0       146030.0  6.579521e+09     45056.0              39639.0
# Toronto  2010.0      4249280.0  1.890000e+11     44478.0              34365.0
# Hamilton 2010.0       543620.0  2.358643e+10     43388.0              37912.0
# Niagara  2010.0       311730.0  1.165963e+10     37403.0              35234.0
# Guelph   2010.0       105740.0  4.749362e+09     44915.0              39958.0
# Barrie   2010.0       140360.0  5.751240e+09     40975.0              38179.0
#
#                  under80K_total_returns  over80K_avg_income  \
# Region   Year
# Toronto  2017.0               3964740.0             92979.0
# Hamilton 2017.0                489400.0             81285.0
# Niagara  2017.0                293690.0             65456.0
# Guelph   2017.0                 97490.0             78722.0
# Barrie   2017.0                128350.0             72991.0
# Toronto  2014.0               3864830.0             86850.0
# Hamilton 2014.0                484570.0             74966.0
# Niagara  2014.0                287130.0             61565.0
# Guelph   2014.0                 94740.0             71105.0
# Barrie   2014.0                124130.0             66527.0
# Toronto  2010.0               3710040.0             80144.0
# Hamilton 2010.0                475800.0             67021.0
# Niagara  2010.0                284290.0             56262.0
# Guelph   2010.0                 91800.0             64239.0
# Barrie   2010.0                123900.0             58258.0
#
#                  over80K_total_returns     10000     15000     20000  ...  \
# Region   Year                                                         ...
# Toronto  2017.0               850050.0  920380.0  420140.0  420270.0  ...
# Hamilton 2017.0               107990.0   83120.0   47220.0   47360.0  ...
# Niagara  2017.0                42230.0   44040.0   29930.0   31280.0  ...
# Guelph   2017.0                23100.0   15910.0    8410.0    8350.0  ...
# Barrie   2017.0                26310.0   21890.0   12720.0   12520.0  ...
# Toronto  2014.0               708440.0  948480.0  430060.0  406980.0  ...
#
#       100000    150000    250000   500000    Region    Year
# 0   151070.0  309470.0  139870.0  80730.0   Toronto  2017.0
# 1    21290.0   39840.0   16240.0   7240.0  Hamilton  2017.0
# 2     9250.0   15360.0    5320.0   2190.0   Niagara  2017.0
# 3     4530.0    8520.0    3610.0   1460.0    Guelph  2017.0
# 4     5710.0    9980.0    3210.0   1210.0    Barrie  2017.0
# 5   128880.0  253980.0  108170.0  65930.0   Toronto  2014.0
# 6    19140.0   33060.0   12380.0   5740.0  Hamilton  2014.0
# 7     7840.0   12940.0    4020.0   1680.0   Niagara  2014.0
# 8     3670.0    6990.0    2680.0   1050.0    Guelph  2014.0
# 9     4830.0    8060.0    2490.0    830.0    Barrie  2014.0
# 10   95840.0  184210.0   79140.0  53280.0   Toronto  2010.0
# 11   13090.0   22600.0    8830.0   4440.0  Hamilton  2010.0
# 12    5600.0    9430.0    2910.0   1420.0   Niagara  2010.0
# 13    2610.0    4870.0    1860.0    780.0    Guelph  2010.0
# 14    3440.0    5720.0    1660.0    690.0    Barrie  2010.0
#
# [15 rows x 26 columns]

# %%
# income = income.groupby(['Region','Year'])
# income
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-280-fbb6cee91a01> in <module>
# ----> 1 income = income.groupby(['Region','Year']).mean()
#       2 income
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
# x_axis = income_area['Year']
# y_axis = income_area['Avg_Income']
# income.plot.line(figsize=(20,10), subplots=False)
# Out:
# Region    Year
# Barrie    2010.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2014.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2017.0    AxesSubplot(0.125,0.125;0.775x0.755)
# Guelph    2010.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2014.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2017.0    AxesSubplot(0.125,0.125;0.775x0.755)
# Hamilton  2010.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2014.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2017.0    AxesSubplot(0.125,0.125;0.775x0.755)
# Niagara   2010.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2014.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2017.0    AxesSubplot(0.125,0.125;0.775x0.755)
# Toronto   2010.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2014.0    AxesSubplot(0.125,0.125;0.775x0.755)
#           2017.0    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
# grouped_income_area = income_area.groupby(['Description','Year'])
# grouped_income_area

# %%
housing_prices = pd.read_csv('Resources/housing_prices.csv')
housing_prices
# Out:
#           Date                 Area  Composite_HPI  Two_Storey_HPI  \
# 0     Jan 2005  Barrie_and_District          100.0           100.0
# 1     Feb 2005  Barrie_and_District          101.5           101.2
# 2     Mar 2005  Barrie_and_District          102.8           102.9
# 3     Apr 2005  Barrie_and_District          103.5           103.4
# 4     May 2005  Barrie_and_District          104.5           104.0
# ...        ...                  ...            ...             ...
# 1119       NaN                  NaN            NaN             NaN
# 1120       NaN                  NaN            NaN             NaN
# 1121       NaN                  NaN            NaN             NaN
# 1122       NaN                  NaN            NaN             NaN
# 1123       NaN                  NaN            NaN             NaN
#
#       Apartment_HPI  Composite_Benchmark  Two_Storey_Benchmark  \
# 0             100.0             209000.0              220600.0
# 1             100.3             212100.0              223200.0
# 2             100.6             214800.0              227000.0
# 3             100.9             216300.0              228100.0
# 4             101.2             218400.0              229400.0
# ...             ...                  ...                   ...
# 1119            NaN                  NaN                   NaN
# 1120            NaN                  NaN                   NaN
# 1121            NaN                  NaN                   NaN
# 1122            NaN                  NaN                   NaN
# 1123            NaN                  NaN                   NaN
#
#       Apartment_Benchmark
# 0                166400.0
# 1                166900.0
# 2                167400.0
# 3                167900.0
# 4                168400.0
# ...                   ...
# 1119                  NaN
# 1120                  NaN
# 1121                  NaN
# 1122                  NaN
# 1123                  NaN
#
# [1124 rows x 8 columns]

# %%
income = pd.read_csv('Resources/Income - Toronto.csv')
income.head()
# Out:
#    REF_DATE               GEO         DGUID         Sex       Age group  \
# 0      2000  Toronto, Ontario  2016S0503535  Both sexes  All age groups
# 1      2000  Toronto, Ontario  2016S0503535  Both sexes  All age groups
# 2      2000  Toronto, Ontario  2016S0503535  Both sexes  All age groups
# 3      2000  Toronto, Ontario  2016S0503535  Both sexes  All age groups
# 4      2000  Toronto, Ontario  2016S0503535  Both sexes  All age groups
#
#                        Persons with income     UOM  UOM_ID SCALAR_FACTOR  \
# 0                Total persons with income  Number     223         units
# 1         Persons with income under $5,000  Number     223         units
# 2   Persons with income of $5,000 and over  Number     223         units
# 3  Persons with income of $10,000 and over  Number     223         units
# 4  Persons with income of $15,000 and over  Number     223         units
#
#    SCALAR_ID     VECTOR COORDINATE    VALUE  STATUS  SYMBOL TERMINATED  \
# 0          0  v20797165   19.1.1.1  3371060     NaN     NaN        NaN
# 1          0  v20797166   19.1.1.2   415550     NaN     NaN        NaN
# 2          0  v20797167   19.1.1.3  2955520     NaN     NaN        NaN
# 3          0  v20797168   19.1.1.4  2584590     NaN     NaN        NaN
# 4          0  v20797169   19.1.1.5  2204370     NaN     NaN        NaN
#
#    DECIMALS
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
housing_prices = housing_prices.dropna()
housing_prices.shape
# Out:
# (1110, 8)

# %% [markdown]
# Original database was relatively clean. Only 14 rows contained na values

# %%
housing_prices[['Month','Year']] = housing_prices.Date.str.split(" ", expand=True)
housing_prices.head()
# Out:
# C:\Users\dlefo\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#        Date                 Area  Composite_HPI  Two_Storey_HPI  \
# 0  Jan 2005  Barrie_and_District          100.0           100.0
# 1  Feb 2005  Barrie_and_District          101.5           101.2
# 2  Mar 2005  Barrie_and_District          102.8           102.9
# 3  Apr 2005  Barrie_and_District          103.5           103.4
# 4  May 2005  Barrie_and_District          104.5           104.0
#
#    Apartment_HPI  Composite_Benchmark  Two_Storey_Benchmark  \
# 0          100.0             209000.0              220600.0
# 1          100.3             212100.0              223200.0
# 2          100.6             214800.0              227000.0
# 3          100.9             216300.0              228100.0
# 4          101.2             218400.0              229400.0
#
#    Apartment_Benchmark Month  Year
# 0             166400.0   Jan  2005
# 1             166900.0   Feb  2005
# 2             167400.0   Mar  2005
# 3             167900.0   Apr  2005
# 4             168400.0   May  2005

# %%
clean_housing_prices = housing_prices[['Area','Year','Month','Composite_Benchmark','Two_Storey_Benchmark','Apartment_Benchmark']]
clean_housing_prices
# Out:
#                      Area  Year Month  Composite_Benchmark  \
# 0     Barrie_and_District  2005   Jan             209000.0
# 1     Barrie_and_District  2005   Feb             212100.0
# 2     Barrie_and_District  2005   Mar             214800.0
# 3     Barrie_and_District  2005   Apr             216300.0
# 4     Barrie_and_District  2005   May             218400.0
# ...                   ...   ...   ...                  ...
# 1105      Oakville_Milton  2020   Jan            1048400.0
# 1106      Oakville_Milton  2020   Feb            1078000.0
# 1107      Oakville_Milton  2020   Mar            1113200.0
# 1108      Oakville_Milton  2020   Apr            1096900.0
# 1109      Oakville_Milton  2020   May            1100000.0
#
#       Two_Storey_Benchmark  Apartment_Benchmark
# 0                 220600.0             166400.0
# 1                 223200.0             166900.0
# 2                 227000.0             167400.0
# 3                 228100.0             167900.0
# 4                 229400.0             168400.0
# ...                    ...                  ...
# 1105             1100600.0             553600.0
# 1106             1137900.0             555400.0
# 1107             1177500.0             565900.0
# 1108             1149300.0             574900.0
# 1109             1148100.0             596600.0
#
# [1110 rows x 6 columns]

# %%
clean_housing_prices.dtypes
# Out:
# Area                     object
# Year                     object
# Month                    object
# Composite_Benchmark     float64
# Two_Storey_Benchmark    float64
# Apartment_Benchmark     float64
# dtype: object

# %%
group_area_year_month = clean_housing_prices.groupby(['Area','Year','Month']).mean()
group_area_year_month
# Out:
#                                 Composite_Benchmark  Two_Storey_Benchmark  \
# Area                Year Month
# Barrie_and_District 2005 Apr               216300.0              228100.0
#                          Aug               221300.0              232300.0
#                          Dec               228600.0              236900.0
#                          Feb               212100.0              223200.0
#                          Jan               209000.0              220600.0
# ...                                             ...                   ...
# Oakville_Milton     2020 Apr              1096900.0             1149300.0
#                          Feb              1078000.0             1137900.0
#                          Jan              1048400.0             1100600.0
#                          Mar              1113200.0             1177500.0
#                          May              1100000.0             1148100.0
#
#                                 Apartment_Benchmark
# Area                Year Month
# Barrie_and_District 2005 Apr               167900.0
#                          Aug               166000.0
#                          Dec               179000.0
#                          Feb               166900.0
#                          Jan               166400.0
# ...                                             ...
# Oakville_Milton     2020 Apr               574900.0
#                          Feb               555400.0
#                          Jan               553600.0
#                          Mar               565900.0
#                          May               596600.0
#
# [1110 rows x 3 columns]

# %%
group_area_year = round(clean_housing_prices.groupby(['Area','Year']).mean(),2)
group_area_year
# Out:
#                           Composite_Benchmark  Two_Storey_Benchmark  \
# Area                Year
# Barrie_and_District 2005            219216.67             230575.00
#                     2006            231550.00             243466.67
#                     2007            242291.67             253441.67
#                     2008            251083.33             262891.67
#                     2009            249108.33             260575.00
# ...                                       ...                   ...
# Oakville_Milton     2016            861641.67             908275.00
#                     2017           1005183.33            1055475.00
#                     2018            980391.67            1023475.00
#                     2019           1013375.00            1060550.00
#                     2020           1087300.00            1142680.00
#
#                           Apartment_Benchmark
# Area                Year
# Barrie_and_District 2005            168883.33
#                     2006            179375.00
#                     2007            188266.67
#                     2008            197891.67
#                     2009            194591.67
# ...                                       ...
# Oakville_Milton     2016            424600.00
#                     2017            502708.33
#                     2018            521750.00
#                     2019            544275.00
#                     2020            569280.00
#
# [96 rows x 3 columns]

# %%
group_area_year.reset_index(level=['Year'])
# Out:
#                      Year  Composite_Benchmark  Two_Storey_Benchmark  \
# Area
# Barrie_and_District  2005            219216.67             230575.00
# Barrie_and_District  2006            231550.00             243466.67
# Barrie_and_District  2007            242291.67             253441.67
# Barrie_and_District  2008            251083.33             262891.67
# Barrie_and_District  2009            249108.33             260575.00
# ...                   ...                  ...                   ...
# Oakville_Milton      2016            861641.67             908275.00
# Oakville_Milton      2017           1005183.33            1055475.00
# Oakville_Milton      2018            980391.67            1023475.00
# Oakville_Milton      2019           1013375.00            1060550.00
# Oakville_Milton      2020           1087300.00            1142680.00
#
#                      Apartment_Benchmark
# Area
# Barrie_and_District            168883.33
# Barrie_and_District            179375.00
# Barrie_and_District            188266.67
# Barrie_and_District            197891.67
# Barrie_and_District            194591.67
# ...                                  ...
# Oakville_Milton                424600.00
# Oakville_Milton                502708.33
# Oakville_Milton                521750.00
# Oakville_Milton                544275.00
# Oakville_Milton                569280.00
#
# [96 rows x 4 columns]

# %%
group_comp = group_area_year.Composite_Benchmark

# %%
group_comp.unstack(level='Area').plot.line(figsize=(20,10), subplots=False)

# %%
group_twostorey = group_area_year.Two_Storey_Benchmark

# %%
group_twostorey.unstack(level='Area').plot.line(figsize=(20,10), subplots=False)

# %%
group_apart = group_area_year.Apartment_Benchmark

# %%
group_apart.unstack(level='Area').plot.line(figsize=(20,10), subplots=False)

# %%
group_gta = group_area_year.reset_index(level='Area')
group_gta = group_gta.loc[group_gta['Area']== 'Greater_Toronto']

# %%
group_gta.plot.line(figsize=(20,10), subplots=False)

# %%
group_hambur = group_area_year.reset_index(level='Area')
group_hambur = group_hambur.loc[group_hambur['Area']== 'Hamilton_Burlington']

# %%
group_hambur.plot.line(figsize=(20,10), subplots=False)

# %%
group_barrie = group_area_year.reset_index(level='Area')
group_barrie = group_barrie.loc[group_barrie['Area']== 'Barrie_and_District']

# %%
group_barrie.plot.line(figsize=(20,10), subplots=False)

# %%
group_oakmilt = group_area_year.reset_index(level='Area')
group_oakmilt = group_oakmilt.loc[group_oakmilt['Area']== 'Oakville_Milton']

# %%
group_oakmilt.plot.line(figsize=(20,10), subplots=False)
