# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# %%
income_area = pd.read_csv('Resources/income_comparison.csv')
income_area = income_area.dropna()
income_area

# %%
# income_area['Avg_Income'] = (income_area['Total_Income'])/(income_area['Total_Returns'])
income = income_area[['Total_Returns', 'Total_Income', 'Avg_Income',
       'under80K_avg_income', 'under80K_total_returns', 'over80K_avg_income',
       'over80K_total_returns', '10000',
       '15000', '20000', '25000', '30000', '35000', '40000', '45000', '50000',
       '60000', '70000', '80000', '90000', '100000', '150000', '250000',
       '500000']].astype(float)

# %%
income[['Region','Year']] = income_area[['Description','Year']]
income.set_index(['Region','Year'])

# %%
income['Avg_Income'] = income['Total_Income']//income['Total_Returns']
income

# %%
# income = income.groupby(['Region','Year'])
# income

# %%
# x_axis = income_area['Year']
# y_axis = income_area['Avg_Income']
# income.plot.line(figsize=(20,10), subplots=False)

# %%
# grouped_income_area = income_area.groupby(['Description','Year'])
# grouped_income_area

# %% [markdown]
# # Income - Analysis

# %% [markdown]
# # Housing Price Over Time - Analysis

# %%
housing_prices_data = pd.read_csv('Resources/housing_prices.csv')

# Determining how many rows in data set
housing_prices_data.shape
# Out:
# (1124, 8)

# %%
# income = pd.read_csv('Resources/Income - Toronto.csv')
# income.head()

# %%
# Dropping n/a values from data set
housing_prices_data = housing_prices_data.dropna()

# Re-determining how many rows in data set
housing_prices_data.shape
# Out:
# (1110, 8)

# %% [markdown]
# Original database was relatively clean. Only 14 rows contained na values

# %%
# Splitting the Date column into Month and Year columns
housing_prices_data[['Month','Year']] = housing_prices_data.Date.str.split(" ", expand=True)

# %%
# Creating a housing prices data frame for analysis
housing_prices = housing_prices_data[['Area','Year','Month','Composite_Benchmark','Two_Storey_Benchmark','Apartment_Benchmark']]

# Rename the columns for clarity
housing_prices = housing_prices.rename(columns = {"Area" : "Region",
                                               "Composite_Benchmark" : "Benchmark Price (Composite)",
                                               "Two_Storey_Benchmark" : "Benchmark Price (Two-Storey)",
                                               "Apartment_Benchmark" : "Benchmark Price (Apartment)"})

# Formatting data frame
housing_prices.style.format({'Benchmark Price (Composite)':'${:,.2f}',
                                    'Benchmark Price (Two-Storey)':'${:,.2f}',
                                    'Benchmark Price (Apartment)':'${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Region</th>        <th class="col_heading level0 col1" >Year</th>        <th class="col_heading level0 col2" >Month</th>        <th class="col_heading level0 col3" >Benchmark Price (Composite)</th>        <th class="col_heading level0 col4" >Benchmark Price (Two-Storey)</th>        <th class="col_heading level0 col5" >Benchmark Price (Apartment)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row0_col0" class="data row0 col0" >Barrie_and_District</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row0_col1" class="data row0 col1" >2005</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row0_col2" class="data row0 col2" >Jan</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row0_col3" class="data row0 col3" >$209,000.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row0_col4" class="data row0 col4" >$220,600.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row0_col5" class="data row0 col5" >$166,400.00</td>
#             </tr>
#             <tr>
#                         <th id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row1_col0" class="data row1 col0" >Barrie_and_District</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row1_col1" class="data row1 col1" >2005</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row1_col2" class="data row1 col2" >Feb</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row1_col3" class="data row1 col3" >$212,100.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row1_col4" class="data row1 col4" >$223,200.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row1_col5" class="data row1 col5" >$166,900.00</td>
#             </tr>
#             <tr>
#                         <th id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row2_col0" class="data row2 col0" >Barrie_and_District</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row2_col1" class="data row2 col1" >2005</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row2_col2" class="data row2 col2" >Mar</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row2_col3" class="data row2 col3" >$214,800.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row2_col4" class="data row2 col4" >$227,000.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row2_col5" class="data row2 col5" >$167,400.00</td>
#             </tr>
#             <tr>
#                         <th id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row3_col0" class="data row3 col0" >Barrie_and_District</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row3_col1" class="data row3 col1" >2005</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row3_col2" class="data row3 col2" >Apr</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row3_col3" class="data row3 col3" >$216,300.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row3_col4" class="data row3 col4" >$228,100.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row3_col5" class="data row3 col5" >$167,900.00</td>
#             </tr>
#             <tr>
#                         <th id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row4_col0" class="data row4 col0" >Barrie_and_District</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row4_col1" class="data row4 col1" >2005</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row4_col2" class="data row4 col2" >May</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row4_col3" class="data row4 col3" >$218,400.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row4_col4" class="data row4 col4" >$229,400.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row4_col5" class="data row4 col5" >$168,400.00</td>
#             </tr>
#             <tr>
#                         <th id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row5_col0" class="data row5 col0" >Barrie_and_District</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row5_col1" class="data row5 col1" >2005</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row5_col2" class="data row5 col2" >Jun</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row5_col3" class="data row5 col3" >$218,200.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row5_col4" class="data row5 col4" >$229,600.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row5_col5" class="data row5 col5" >$168,900.00</td>
#             </tr>
#             <tr>
#                         <th id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row6_col0" class="data row6 col0" >Barrie_and_District</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row6_col1" class="data row6 col1" >2005</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row6_col2" class="data row6 col2" >Jul</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row6_col3" class="data row6 col3" >$220,500.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row6_col4" class="data row6 col4" >$233,800.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row6_col5" class="data row6 col5" >$167,400.00</td>
#             </tr>
#             <tr>
#                         <th id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row7_col0" class="data row7 col0" >Barrie_and_District</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row7_col1" class="data row7 col1" >2005</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row7_col2" class="data row7 col2" >Aug</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row7_col3" class="data row7 col3" >$221,300.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row7_col4" class="data row7 col4" >$232,300.00</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row7_col5" class="data row7 col5" >$166,000.00</td>
#             </tr>
#             <tr>
#                         <th id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row8_col0" class="data row8 col0" >Barrie_and_District</td>
#                         <td id="T_f6cd22e6_ca35_11ea_826e_382c4a71c557row8_col1" class="data row8 co

# %%
# Grouping the housing prices by Region and Year and calculating the mean house prices
group_region_year = round(housing_prices.groupby(['Region','Year']).mean(),2)

# %%
# Removing Year from index and adding to a column in df
group_region_year.reset_index(level=['Year'])
# Out:
#                      Year  Benchmark Price (Composite)  \
# Region
# Barrie_and_District  2005                    219216.67
# Barrie_and_District  2006                    231550.00
# Barrie_and_District  2007                    242291.67
# Barrie_and_District  2008                    251083.33
# Barrie_and_District  2009                    249108.33
# ...                   ...                          ...
# Oakville_Milton      2016                    861641.67
# Oakville_Milton      2017                   1005183.33
# Oakville_Milton      2018                    980391.67
# Oakville_Milton      2019                   1013375.00
# Oakville_Milton      2020                   1087300.00
#
#                      Benchmark Price (Two-Storey)  Benchmark Price (Apartment)
# Region
# Barrie_and_District                     230575.00                    168883.33
# Barrie_and_District                     243466.67                    179375.00
# Barrie_and_District                     253441.67                    188266.67
# Barrie_and_District                     262891.67                    197891.67
# Barrie_and_District                     260575.00                    194591.67
# ...                                           ...                          ...
# Oakville_Milton                         908275.00                    424600.00
# Oakville_Milton                        1055475.00                    502708.33
# Oakville_Milton                        1023475.00                    521750.00
# Oakville_Milton                        1060550.00                    544275.00
# Oakville_Milton                        1142680.00                    569280.00
#
# [96 rows x 4 columns]

# %%
# Selecting composite price group to plot
group_comp = group_region_year['Benchmark Price (Composite)']

# Unstacking df and plotting on a line plot
group_comp.unstack(level='Region').plot.line(figsize=(15,10), subplots=False)

# Adding labels to chart
plt.title('Housing Price per Region')
plt.ylabel('Price ($)')

# Saving and displaying plot
plt.savefig('Figures/Housing Price per Region.png')
plt.show()

# %%
# Removing Region from index and adding to a column in df
group_gta = group_region_year.reset_index(level='Region')

# Isolating for only the GTA region
group_gta = group_gta.loc[group_gta['Region']== 'Greater_Toronto']

# Plotting GTA housing prices over time
group_gta.plot.line(figsize=(15,10), subplots=False)

# Adding labels to chart
plt.title('GTA Housing Price Over Time')
plt.ylabel('Price ($)')

# Saving and displaying plot
plt.savefig('Figures/GTA Housing Price Over Time.png')
plt.show()

# %% [markdown]
# ### Graphs to remove

# %%
# group_twostorey = group_area_year.Two_Storey_Benchmark

# %%
# group_twostorey.unstack(level='Region').plot.line(figsize=(20,10), subplots=False)

# %%
# group_apart = group_area_year.Apartment_Benchmark

# %%
# group_apart.unstack(level='Region').plot.line(figsize=(20,10), subplots=False)

# %%
# group_hambur = group_area_year.reset_index(level='Region')
# group_hambur = group_hambur.loc[group_hambur['Region']== 'Hamilton_Burlington']

# %%
# group_hambur.plot.line(figsize=(20,10), subplots=False)

# %%
# group_barrie = group_area_year.reset_index(level='Region')
# group_barrie = group_barrie.loc[group_barrie['Region']== 'Barrie_and_District']

# %%
# group_barrie.plot.line(figsize=(20,10), subplots=False)

# %%
# group_oakmilt = group_area_year.reset_index(level='Region')
# group_oakmilt = group_oakmilt.loc[group_oakmilt['Region']== 'Oakville_Milton']

# %%
# group_oakmilt.plot.line(figsize=(20,10), subplots=False)
